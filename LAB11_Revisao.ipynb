# %% [markdown]
# <a href="https://colab.research.google.com/github/guirco/ufpel-pdi/blob/main/LAB11_Revisao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB11 — Revisão do Conteúdo
#
# Disciplina: **Processamento Digital de Imagens (PDI)** – UFPel
# Professor: **Guilherme Corrêa**

# %% [markdown]
# ## Bibliotecas úteis
# **Se estiver no Colab, rode a célula de instalação uma única vez.**

# %%
# Se estiver no Colab, descomente a linha abaixo para garantir o OpenCV instalado
# !pip install opencv-python
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import files

# %% [markdown]
# # Exercício 1: Borramento e Suavização
#
# Crie um processo para borrar a imagem `tuyuka.png` como no exemplo abaixo.
#
# Neste exercício, faça o processamento no **domínio espacial**.
#
# ![revisao01.png](data:image/png;base64,...)

# %% [markdown]
# # Exercício 2: Realce
#
# Crie um processo para realçar a imagem `tuyuka.png` como no exemplo abaixo.
#
# Neste exercício, faça o processamento no **domínio das frequências**.
#
# ![revisao02.png](data:image/png;base64,...)

# %% [markdown]
# # Exercício 3: Remoção de Ruído
#
# Crie um processo para remoção de ruído da imagem `tuyuka_lq.png` como no exemplo abaixo. Após a remoção do ruído, aumente a resolução da imagem.
#
# Neste exercício, você pode combinar processamento **no domínio espacial e no domínio das frequências**.
#
# ![revisao03.png](data:image/png;base64,...)

# %% [markdown]
# # Exercício 4: Compressão de Imagens
#
# Crie um processo para reduzir o número de bytes da imagem `tuyuka.png` como no exemplo abaixo.
#
# Utilize o **padrão JPEG** para a compressão.
#
# ![revisao04.png](data:image/png;base64,...)
